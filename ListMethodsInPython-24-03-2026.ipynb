# %%
abubakar = []

# %%
abubakar = ['Ali', 123, 30.0]

# %%
abubakar[0]
# Out:
# 'Ali'

# %%
type(abubakar[0])
# Out:
# str

# %%
abubakar[-1]
# Out:
# 30.0

# %%
abubakar[0] = 'Saahir Lodhi'

# %%
abubakar[0]
# Out:
# 'Saahir Lodhi'

# %%
abubakar
# Out:
# ['Saahir Lodhi', 123, 30.0]

# %%
abubakar.append("Sir Jehanzeb")

# %%
abubakar
# Out:
# ['Saahir Lodhi', 123, 30.0, 'Sir Jehanzeb', 'Sir Jehanzeb']

# %%
abubakar.remove("Sir Jehanzeb")
#remove looks for and removes only 1 instance from left to right

# %%
abubakar
# Out:
# ['Saahir Lodhi', 123, 30.0, 'Sir Jehanzeb']

# %%
#2 methods for removing single elements from a list list.remove() and list.pop
#pop() takes the index of the element to remove as an argument 
#remove() takes the string to remove from the list as an argument

# %%
abubakar.clear()

# %%
abubakar
# Out:
# []

# %%
abubakar = []un

abubakar2 = abubakar

# %%
abubakar.reverse()

# %%
abubakar
# Out:
# [2, 'Saahir Lodhi', 19.0, 23, 'waqar zaka', 'Saahir Lodhi']

# %%
unsortedlist = [12223,5,245,3,73,0,20,20,153,27,55,47,84,22]

# %%
unsortedlist
# Out:
# [12223, 5, 245, 3, 73, 0, 20, 20, 153, 27, 55, 47, 84, 22]

# %%
unsortedlist.sort()

# %%
unsortedlist
# Out:
# [0, 3, 5, 20, 20, 22, 27, 47, 55, 73, 84, 153, 245, 12223]

# %%
max(unsortedlist)
# Out:
# 12223

# %%
sum(unsortedlist)
# Out:
# 12977

# %%
#list comprehension automatically fills a list (takes less effort)

# %%
squares = [x**2 for x in range(10)]

# %%
squares
# Out:
# [0, 1, 4, 9, 16, 25, 36, 49, 64, 81]
